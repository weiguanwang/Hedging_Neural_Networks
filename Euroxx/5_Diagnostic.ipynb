# %%
import sys
import os
# Append the library path to PYTHONPATH, so library can be imported.
sys.path.append(os.path.dirname(os.getcwd()))
import itertools
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from library import common as cm

# %%
# %run setup.py
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

sns.set(style='darkgrid')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cols = ['FREQ=1H_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False',
        'FREQ=1D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False',
        'FREQ=2D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False'
       ]

# %%
# Cols are different data sets, rows are different experiments.
rows = ['Regression/No_Hedge', 'Regression/BS_Benchmark', 'Regression/Fixed_Constants',
        'Regression/Delta_only', 'Regression/Vega_only', 'Regression/Gamma_only', 'Regression/Vanna_only',
        'Regression/Delta_Gamma', 'Regression/Delta_Vega', 
        'Regression/Delta_Vanna', 
        'Regression/Delta_Vega_Gamma', 'Regression/Delta_Vega_Vanna', 'Regression/Delta_Gamma_Vanna',
        'Regression/Delta_Vega_Gamma_Vanna',
        'Regression/Hull_White', 'Regression/Hull_White_relaxed',
        'Network/Normal_Feature', 'Network/Delta_Vega']

# %%
def run_save_tables(dirs, agg, measure, op_type):
    df_res = inspector.evalPnls(df_dirs, aggregating=aggregating, measure=measure, op_type=op_type)
    if op_type == None:
        file = f'{DATA_DIR}Result/call_and_put_{measure}.csv'
    else:
        file = f'{DATA_DIR}Result/{op_type}_{measure}.csv'
    with open(file, 'w+') as f:
        f.write(f'{datetime.datetime.now()}\n{op_type}_{measure}\n')
    (df_res).to_csv(file, mode='a') 
    return df_res

# %%
df_dirs = pd.DataFrame(columns=cols, index=rows)

for x, y in list(itertools.product(rows, cols)):
    df_dirs.loc[x, y] = f'{DATA_DIR}Result/{y}/{x}/'

# %%
inspector = cm.Inspector()

# %%
aggregating = 'mean'
measure = 'mse'

# %%
run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type=None)
# Out:
# setup                             FREQ=1H_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False  \
# value                                                                                                                                                    Absolute
# Regression/No_Hedge                                                            0.462
# Regression/BS_Benchmark                                                        0.087
# Regression/Fixed_Constants                                                     0.078
# Regression/Delta_only                                                          0.081
# Regression/Vega_only                                                           0.078
# Regression/Gamma_only                                                          0.086
# Regression/Vanna_only                                                          0.083
# Regression/Delta_Gamma                                                         0.080
# Regression/Delta_Vega                                                          0.078
# Regression/Delta_Vanna                                                         0.081
# Regression/Delta_Vega_Gamma                                                    0.078
# Regression/Delta_Vega_Vanna                                                    0.079
# Regression/Delta_Gamma_Vanna                                                   0.079
# Regression/Delta_Vega_Gamma_Vanna                                              0.078
# Regression/Hull_White                                                          0.080
# Regression/Hull_White_relaxed                                                  0.080
# Network/Normal_Feature                                                         0.075
# Network/Delta_Vega                                                             0.079
#
# setup                                      \
# value                             %Change
# Regression/No_Hedge                433.58
# Regression/BS_Benchmark              0.00
# Regression/Fixed_Constants          -9.88
# Regression/Delta_only               -5.92
# Regression/Vega_only                -9.64
# Regression/Gamma_only               -0.06
# Regression/Vanna_only               -4.33
# Regression/Delta_Gamma              -7.53
# Regression/Delta_Vega               -9.40
# Regression/Delta_Vanna              -6.05
# Regression/Delta_Vega_Gamma         -9.45
# Regression/Delta_Vega_Vanna         -9.00
# Regression/Delta_Gamma_Vanna        -8.74
# Regression/Delta_Vega_Gamma_Vanna   -9.46
# Regression/Hull_White               -7.14
# Regression/Hull_White_relaxed       -7.28
# Network/Normal_Feature             -13.19
# Network/Delta_Vega                  -9.08
#
# setup                             FREQ=1D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False  \
# value                                                                                                                                                    Absolute
# Regression/No_Hedge                                                            6.091
# Regression/BS_Benchmark                                                        1.151
# Regression/Fixed_Constants                                                     1.003
# Regression/Delta_only                                                          1.035
# Regression/Vega_only                                                           0.993
# Regression/Gamma_only                                                          1.082
# Regression/Vanna_only                                                          1.022
# Regression/Delta_Gamma                                                         1.078
# Regression/Delta_Vega                                                          1.000
# Regression/Delta_Vanna                                                         1.034
# Regression/Delta_Vega_Gamma                                                    1.048
# Regression/Delta_Vega_Vanna                                                    1.018
# Regression/Delta_Gamma_Vanna                                                   1.034
# Regression/Delta_Vega_Gamma_Vanna                                              1.030
# Regression/Hull_White                                                          1.016
# Regression/Hull_White_relaxed                                                  1.015
# Network/Normal_Feature                                                         1.231
# Network/Delta_Vega                                                             1.086
#
# setup                                      \
# value                             %Change
# Regression/No_Hedge                429.11
# Regression/BS_Benchmark              0.00
# Regression/Fixed_Constants         -12.89
# Regression/Delta_only              -10.09
# Regression/Vega_only               -13.73
# Regression/Gamma_only               -6.02
# Regression/Vanna_only              -11.18
# Regression/Delta_Gamma              -6.32
# Regression/Delta_Vega              -13.12
# Regression/Delta_Vanna             -10.17
# Regression/Delta_Vega_Gamma         -8.99
# Regression/Delta_Vega_Vanna        -11.58
# Regression/Delta_Gamma_Vanna       -10.17
# Regression/Delta_Vega_Gamma_Vanna  -10.48
# Regression/Hull_White              -11.76
# Regression/Hull_White_relaxed      -11.81
# Network/Normal_Feature               6.90
# Network/Delta_Vega                  -5.62
#
# setup                             FREQ=2D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False  \
# value                                                                                                                                                    Absolute
# Regression/No_Hedge                                                           10.478
# Regression/BS_Benchmark                                                        1.981
# Regression/Fixed_Constants                                                     1.715
# Regression/Delta_only                                                          1.807
# Regression/Vega_only                                                           1.736
# Regression/Gamma_only                                                          1.886
# Regression/Vanna_only                                                          1.818
# Regression/Delta_Gamma                                                         1.831
# Regression/Delta_Vega                                                          1.740
# Regression/Delta_Vanna                                                         1.787
# Regression/Delta_Vega_Gamma                                                    1.762
# Regression/Delta_Vega_Vanna                                                    1.747
# Regression/Delta_Gamma_Vanna                                                   1.774
# Regression/Delta_Vega_Gamma_Vanna                                              1.759
# Regression/Hull_White                                                          1.805
# Regression/Hull_White_relaxed                                                  1.808
# Network/Normal_Feature                                                         1.801
# Network/Delta_Vega                                                             1.719
#
# setup
# value                             %Change
# Regression/No_Hedge                429.00
# Regression/BS_Benchmark              0.00
# Regression/Fixed_Constants         -13.40
# Regression/Delta_only               -8.79
# Regression/Vega_only               -12.34
# Regression/Gamma_only               -4.77
# Regression/Vanna_only               -8.21
# Regression/Delta_Gamma              -7.57
# Regression/Delta_Vega              -12.17
# Regression/Delta_Vanna              -9.76
# Regression/Delta_Vega_Gamma        -11.06
# Regression/Delta_Vega_Vanna        -11.80
# Regression/Delta_Gamma_Vanna       -10.42
# Regression/Delta_Vega_Gamma_Vanna  -11.20
# Regression/Hull_White               -8.86
# Regression/Hull_White_relaxed       -8.72
# Network/Normal_Feature              -9.07
# Network/Delta_Vega                 -13.22

# %%
run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='call')
# Out:
# setup                             FREQ=1H_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False  \
# value                                                                                                                                                    Absolute
# Regression/No_Hedge                                                            0.314
# Regression/BS_Benchmark                                                        0.063
# Regression/Fixed_Constants                                                     0.055
# Regression/Delta_only                                                          0.057
# Regression/Vega_only                                                           0.054
# Regression/Gamma_only                                                          0.062
# Regression/Vanna_only                                                          0.057
# Regression/Delta_Gamma                                                         0.058
# Regression/Delta_Vega                                                          0.054
# Regression/Delta_Vanna                                                         0.057
# Regression/Delta_Vega_Gamma                                                    0.055
# Regression/Delta_Vega_Vanna                                                    0.055
# Regression/Delta_Gamma_Vanna                                                   0.056
# Regression/Delta_Vega_Gamma_Vanna                                              0.055
# Regression/Hull_White                                                          0.056
# Regression/Hull_White_relaxed                                                  0.056
# Network/Normal_Feature                                                         0.056
# Network/Delta_Vega                                                             0.055
#
# setup                                      \
# value                             %Change
# Regression/No_Hedge                400.35
# Regression/BS_Benchmark              0.00
# Regression/Fixed_Constants         -12.48
# Regression/Delta_only               -8.47
# Regression/Vega_only               -13.87
# Regression/Gamma_only               -1.70
# Regression/Vanna_only               -9.39
# Regression/Delta_Gamma              -7.52
# Regression/Delta_Vega              -13.44
# Regression/Delta_Vanna              -9.86
# Regression/Delta_Vega_Gamma        -11.98
# Regression/Delta_Vega_Vanna        -12.74
# Regression/Delta_Gamma_Vanna       -10.84
# Regression/Delta_Vega_Gamma_Vanna  -12.17
# Regression/Hull_White              -10.15
# Regression/Hull_White_relaxed      -10.45
# Network/Normal_Feature             -10.97
# Network/Delta_Vega                 -13.03
#
# setup                             FREQ=1D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False  \
# value                                                                                                                                                    Absolute
# Regression/No_Hedge                                                            3.993
# Regression/BS_Benchmark                                                        0.873
# Regression/Fixed_Constants                                                     0.729
# Regression/Delta_only                                                          0.712
# Regression/Vega_only                                                           0.719
# Regression/Gamma_only                                                          0.747
# Regression/Vanna_only                                                          0.778
# Regression/Delta_Gamma                                                         0.748
# Regression/Delta_Vega                                                          0.705
# Regression/Delta_Vanna                                                         0.721
# Regression/Delta_Vega_Gamma                                                    0.739
# Regression/Delta_Vega_Vanna                                                    0.723
# Regression/Delta_Gamma_Vanna                                                   0.748
# Regression/Delta_Vega_Gamma_Vanna                                              0.747
# Regression/Hull_White                                                          0.721
# Regression/Hull_White_relaxed                                                  0.720
# Network/Normal_Feature                                                         0.884
# Network/Delta_Vega                                                             0.755
#
# setup                                      \
# value                             %Change
# Regression/No_Hedge                357.52
# Regression/BS_Benchmark              0.00
# Regression/Fixed_Constants         -16.43
# Regression/Delta_only              -18.45
# Regression/Vega_only               -17.57
# Regression/Gamma_only              -14.41
# Regression/Vanna_only              -10.86
# Regression/Delta_Gamma             -14.32
# Regression/Delta_Vega              -19.20
# Regression/Delta_Vanna             -17.38
# Regression/Delta_Vega_Gamma        -15.33
# Regression/Delta_Vega_Vanna        -17.17
# Regression/Delta_Gamma_Vanna       -14.26
# Regression/Delta_Vega_Gamma_Vanna  -14.45
# Regression/Hull_White              -17.34
# Regression/Hull_White_relaxed      -17.47
# Network/Normal_Feature               1.33
# Network/Delta_Vega                 -13.45
#
# setup                             FREQ=2D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_WINDOW=90D_AGGSIDE=False_MATCHING=0.1H_CLOSENESS=False  \
# value                                                                                                                                                    Absolute
# Regression/No_Hedge                                                            6.958
# Regression/BS_Benchmark                                                        1.757
# Regression/Fixed_Constants                                                     1.469
# Regression/Delta_only                                                          1.487
# Regression/Vega_only                                                           1.446
# Regression/Gamma_only                                                          1.568
# Regression/Vanna_only                                                          1.554
# Regression/Delta_Gamma                                                         1.506
# Regression/Delta_Vega                                                          1.457
# Regression/Delta_Vanna                                                         1.492
# Regression/Delta_Vega_Gamma                                                    1.477
# Regression/Delta_Vega_Vanna                                                    1.477
# Regression/Delta_Gamma_Vanna                                                   1.491
# Regression/Delta_Vega_Gamma_Vanna                                              1.477
# Regression/Hull_White                                                          1.498
# Regression/Hull_White_relaxed                                                  1.500
# Network/Normal_Feature                                                         1.499
# Network/Delta_Vega                                                             1.458
#
# setup
# value                             %Change
# Regression/No_Hedge                296.00
# Regression/BS_Benchmark              0.00
# Regression/Fixed_Constants         -16.42
# Regression/Delta_only              -15.37
# Regression/Vega_only               -17.73
# Regression/Gamma_only              -10.77
# Regression/Vanna_only              -11.57
# Regression/Delta_Gamma             -14.32
# Regression/Delta_Vega              -17.08
# Regression/Delta_Vanna             -15.06
# Regression/Delta_Vega_Gamma        -15.96
# Regression/Delta_Vega_Vanna        -15.93
# Regression/Delta_Gamma_Vanna       -15.14
# Regression/Delta_Vega_Gamma_Vanna  -15.94
# Regression/Hull_White              -14.76
# Regression/Hull_White_relaxed      -14.61
# Network/Normal_Feature             -14.68
# Network/Delta_Vega                 -17.00

# %%
run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='put')

# %% [raw]
# aggregating = 'mean'
# measure = 'median'
#
# run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type=None)
# run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='call')
# run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='put')
