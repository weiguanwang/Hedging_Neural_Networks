# %%
import sys
import os
# Append the library path to PYTHONPATH, so library can be imported.
sys.path.append(os.path.dirname(os.getcwd()))
import itertools
import datetime

import numpy as np
import pandas as pd

from library import common as cm

# %%
# %run setup.py
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Cols are different data sets, rows are different experiments.
cols = ['FREQ=1D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False',
        'FREQ=2D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False',
       ]
rows = ['Regression/No_Hedge', 'Regression/BS_Benchmark', 'Regression/Fixed_Constants',
        'Regression/Delta_only', 'Regression/Vega_only', 'Regression/Gamma_only','Regression/Vanna_only',  
        #'Regression/Bias',
        'Regression/Delta_Gamma', 'Regression/Delta_Vega',   'Regression/Delta_Vanna',
        #'Regression/Delta_Bias',
        'Regression/Delta_Vega_Gamma', 'Regression/Delta_Vega_Vanna', 'Regression/Delta_Gamma_Vanna',   
        'Regression/Delta_Vega_Gamma_Va', 
        'Regression/Hull_White', 'Regression/Hull_White_relaxed',
        'Network/Normal_Feature', 'Network/Delta_Vega']

# %%
def run_save_tables(dirs, agg, measure, op_type):
    df_res = inspector.evalPnls(df_dirs, aggregating=aggregating, measure=measure, op_type=op_type)
    if op_type == None:
        file = f'{DATA_DIR}Result/call_and_put_{measure}.csv'
    else:
        file = f'{DATA_DIR}Result/{op_type}_{measure}.csv'
    with open(file, 'w+') as f:
        f.write(f'{datetime.datetime.now()}\n{op_type}_{measure}\n')
    (df_res).to_csv(file, mode='a') 
    return df_res

# %%
df_dirs = pd.DataFrame(columns=cols, index=rows)
for x, y in list(itertools.product(rows, cols)):
    df_dirs.loc[x, y] = f'{DATA_DIR}Result/{y}/{x}/'

# %%
inspector = cm.Inspector()

# %%
aggregating = 'mean'
measure = 'mse'

# %%
run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type=None)
# Out:
# /Users/rufj/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# setup                          FREQ=1D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False  \
# value                                                                                                                                                      Absolute
# Regression/No_Hedge                                                         4.542
# Regression/BS_Benchmark                                                     0.665
# Regression/Fixed_Constants                                                  0.566
# Regression/Delta_only                                                       0.553
# Regression/Vega_only                                                        0.583
# Regression/Gamma_only                                                       0.587
# Regression/Vanna_only                                                       0.582
# Regression/Delta_Gamma                                                      0.552
# Regression/Delta_Vega                                                       0.552
# Regression/Delta_Vanna                                                      0.542
# Regression/Delta_Vega_Gamma                                                 0.552
# Regression/Delta_Vega_Vanna                                                 0.541
# Regression/Delta_Gamma_Vanna                                                0.542
# Regression/Delta_Vega_Gamma_Va                                              0.542
# Regression/Hull_White                                                       0.539
# Regression/Hull_White_relaxed                                               0.539
# Network/Normal_Feature                                                        NaN
# Network/Delta_Vega                                                          0.539
#
# setup                                   \
# value                          %Change
# Regression/No_Hedge             583.01
# Regression/BS_Benchmark           0.00
# Regression/Fixed_Constants      -14.83
# Regression/Delta_only           -16.87
# Regression/Vega_only            -12.31
# Regression/Gamma_only           -11.79
# Regression/Vanna_only           -12.51
# Regression/Delta_Gamma          -16.95
# Regression/Delta_Vega           -17.00
# Regression/Delta_Vanna          -18.50
# Regression/Delta_Vega_Gamma     -16.96
# Regression/Delta_Vega_Vanna     -18.69
# Regression/Delta_Gamma_Vanna    -18.49
# Regression/Delta_Vega_Gamma_Va  -18.48
# Regression/Hull_White           -18.89
# Regression/Hull_White_relaxed   -18.91
# Network/Normal_Feature             NaN
# Network/Delta_Vega              -18.94
#
# setup                          FREQ=2D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False  \
# value                                                                                                                                                      Absolute
# Regression/No_Hedge                                                         9.293
# Regression/BS_Benchmark                                                     1.553
# Regression/Fixed_Constants                                                  1.358
# Regression/Delta_only                                                       1.337
# Regression/Vega_only                                                        1.395
# Regression/Gamma_only                                                       1.363
# Regression/Vanna_only                                                       1.363
# Regression/Delta_Gamma                                                      1.330
# Regression/Delta_Vega                                                       1.337
# Regression/Delta_Vanna                                                      1.303
# Regression/Delta_Vega_Gamma                                                 1.328
# Regression/Delta_Vega_Vanna                                                 1.301
# Regression/Delta_Gamma_Vanna                                                1.304
# Regression/Delta_Vega_Gamma_Va                                              1.309
# Regression/Hull_White                                                       1.312
# Regression/Hull_White_relaxed                                               1.308
# Network/Normal_Feature                                                        NaN
# Network/Delta_Vega                                                          1.343
#
# setup
# value                          %Change
# Regression/No_Hedge             498.39
# Regression/BS_Benchmark           0.00
# Regression/Fixed_Constants      -12.55
# Regression/Delta_only           -13.88
# Regression/Vega_only            -10.19
# Regression/Gamma_only           -12.20
# Regression/Vanna_only           -12.23
# Regression/Delta_Gamma          -14.37
# Regression/Delta_Vega           -13.93
# Regression/Delta_Vanna          -16.11
# Regression/Delta_Vega_Gamma     -14.50
# Regression/Delta_Vega_Vanna     -16.23
# Regression/Delta_Gamma_Vanna    -16.01
# Regression/Delta_Vega_Gamma_Va  -15.71
# Regression/Hull_White           -15.53
# Regression/Hull_White_relaxed   -15.79
# Network/Normal_Feature             NaN
# Network/Delta_Vega              -13.52

# %%
run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='call')
# Out:
# setup                          FREQ=1D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False  \
# value                                                                                                                                                      Absolute
# Regression/No_Hedge                                                         4.007
# Regression/BS_Benchmark                                                     0.687
# Regression/Fixed_Constants                                                  0.559
# Regression/Delta_only                                                       0.541
# Regression/Vega_only                                                        0.593
# Regression/Gamma_only                                                       0.580
# Regression/Vanna_only                                                       0.601
# Regression/Delta_Gamma                                                      0.538
# Regression/Delta_Vega                                                       0.539
# Regression/Delta_Vanna                                                      0.532
# Regression/Delta_Vega_Gamma                                                 0.539
# Regression/Delta_Vega_Vanna                                                 0.528
# Regression/Delta_Gamma_Vanna                                                0.531
# Regression/Delta_Vega_Gamma_Va                                              0.529
# Regression/Hull_White                                                       0.528
# Regression/Hull_White_relaxed                                               0.528
# Network/Normal_Feature                                                        NaN
# Network/Delta_Vega                                                          0.526
#
# setup                                   \
# value                          %Change
# Regression/No_Hedge             483.67
# Regression/BS_Benchmark           0.00
# Regression/Fixed_Constants      -18.57
# Regression/Delta_only           -21.26
# Regression/Vega_only            -13.68
# Regression/Gamma_only           -15.46
# Regression/Vanna_only           -12.42
# Regression/Delta_Gamma          -21.59
# Regression/Delta_Vega           -21.42
# Regression/Delta_Vanna          -22.58
# Regression/Delta_Vega_Gamma     -21.48
# Regression/Delta_Vega_Vanna     -23.06
# Regression/Delta_Gamma_Vanna    -22.58
# Regression/Delta_Vega_Gamma_Va  -22.90
# Regression/Hull_White           -23.10
# Regression/Hull_White_relaxed   -23.16
# Network/Normal_Feature             NaN
# Network/Delta_Vega              -23.38
#
# setup                          FREQ=2D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False  \
# value                                                                                                                                                      Absolute
# Regression/No_Hedge                                                         8.307
# Regression/BS_Benchmark                                                     1.583
# Regression/Fixed_Constants                                                  1.343
# Regression/Delta_only                                                       1.325
# Regression/Vega_only                                                        1.418
# Regression/Gamma_only                                                       1.354
# Regression/Vanna_only                                                       1.415
# Regression/Delta_Gamma                                                      1.313
# Regression/Delta_Vega                                                       1.324
# Regression/Delta_Vanna                                                      1.303
# Regression/Delta_Vega_Gamma                                                 1.318
# Regression/Delta_Vega_Vanna                                                 1.297
# Regression/Delta_Gamma_Vanna                                                1.302
# Regression/Delta_Vega_Gamma_Va                                              1.307
# Regression/Hull_White                                                       1.301
# Regression/Hull_White_relaxed                                               1.293
# Network/Normal_Feature                                                        NaN
# Network/Delta_Vega                                                          1.313
#
# setup
# value                          %Change
# Regression/No_Hedge             424.86
# Regression/BS_Benchmark           0.00
# Regression/Fixed_Constants      -15.14
# Regression/Delta_only           -16.30
# Regression/Vega_only            -10.38
# Regression/Gamma_only           -14.47
# Regression/Vanna_only           -10.62
# Regression/Delta_Gamma          -17.05
# Regression/Delta_Vega           -16.35
# Regression/Delta_Vanna          -17.67
# Regression/Delta_Vega_Gamma     -16.72
# Regression/Delta_Vega_Vanna     -18.06
# Regression/Delta_Gamma_Vanna    -17.73
# Regression/Delta_Vega_Gamma_Va  -17.40
# Regression/Hull_White           -17.81
# Regression/Hull_White_relaxed   -18.32
# Network/Normal_Feature             NaN
# Network/Delta_Vega              -17.07

# %%
run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='put')
# Out:
# setup                          FREQ=1D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False  \
# value                                                                                                                                                      Absolute
# Regression/No_Hedge                                                         4.781
# Regression/BS_Benchmark                                                     0.655
# Regression/Fixed_Constants                                                  0.570
# Regression/Delta_only                                                       0.558
# Regression/Vega_only                                                        0.579
# Regression/Gamma_only                                                       0.589
# Regression/Vanna_only                                                       0.573
# Regression/Delta_Gamma                                                      0.559
# Regression/Delta_Vega                                                       0.558
# Regression/Delta_Vanna                                                      0.547
# Regression/Delta_Vega_Gamma                                                 0.558
# Regression/Delta_Vega_Vanna                                                 0.546
# Regression/Delta_Gamma_Vanna                                                0.547
# Regression/Delta_Vega_Gamma_Va                                              0.548
# Regression/Hull_White                                                       0.545
# Regression/Hull_White_relaxed                                               0.544
# Network/Normal_Feature                                                        NaN
# Network/Delta_Vega                                                          0.545
#
# setup                                   \
# value                          %Change
# Regression/No_Hedge             629.53
# Regression/BS_Benchmark           0.00
# Regression/Fixed_Constants      -13.07
# Regression/Delta_only           -14.81
# Regression/Vega_only            -11.66
# Regression/Gamma_only           -10.07
# Regression/Vanna_only           -12.55
# Regression/Delta_Gamma          -14.77
# Regression/Delta_Vega           -14.93
# Regression/Delta_Vanna          -16.59
# Regression/Delta_Vega_Gamma     -14.84
# Regression/Delta_Vega_Vanna     -16.64
# Regression/Delta_Gamma_Vanna    -16.58
# Regression/Delta_Vega_Gamma_Va  -16.41
# Regression/Hull_White           -16.91
# Regression/Hull_White_relaxed   -16.92
# Network/Normal_Feature             NaN
# Network/Delta_Vega              -16.87
#
# setup                          FREQ=2D_HALFMONEY=otm_MINM=0.8_MAXM=1.5_MINTAU=0_Permute=False_VIX=False_MISSING=replace_missing_WINDOW=180D_KickTmrZeroVolume=False  \
# value                                                                                                                                                      Absolute
# Regression/No_Hedge                                                         9.734
# Regression/BS_Benchmark                                                     1.540
# Regression/Fixed_Constants                                                  1.365
# Regression/Delta_only                                                       1.343
# Regression/Vega_only                                                        1.384
# Regression/Gamma_only                                                       1.368
# Regression/Vanna_only                                                       1.340
# Regression/Delta_Gamma                                                      1.337
# Regression/Delta_Vega                                                       1.342
# Regression/Delta_Vanna                                                      1.303
# Regression/Delta_Vega_Gamma                                                 1.332
# Regression/Delta_Vega_Vanna                                                 1.303
# Regression/Delta_Gamma_Vanna                                                1.305
# Regression/Delta_Vega_Gamma_Va                                              1.310
# Regression/Hull_White                                                       1.317
# Regression/Hull_White_relaxed                                               1.314
# Network/Normal_Feature                                                        NaN
# Network/Delta_Vega                                                          1.357
#
# setup
# value                          %Change
# Regression/No_Hedge             532.22
# Regression/BS_Benchmark           0.00
# Regression/Fixed_Constants      -11.36
# Regression/Delta_only           -12.76
# Regression/Vega_only            -10.10
# Regression/Gamma_only           -11.16
# Regression/Vanna_only           -12.97
# Regression/Delta_Gamma          -13.13
# Regression/Delta_Vega           -12.82
# Regression/Delta_Vanna          -15.40
# Regression/Delta_Vega_Gamma     -13.48
# Regression/Delta_Vega_Vanna     -15.39
# Regression/Delta_Gamma_Vanna    -15.22
# Regression/Delta_Vega_Gamma_Va  -14.94
# Regression/Hull_White           -14.48
# Regression/Hull_White_relaxed   -14.63
# Network/Normal_Feature             NaN
# Network/Delta_Vega              -11.88

# %% [raw]
# aggregating = 'mean'
# measure = 'median'
#
# run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type=None)
#
# run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='call')
#
# run_save_tables(df_dirs, agg=aggregating, measure=measure, op_type='put')
